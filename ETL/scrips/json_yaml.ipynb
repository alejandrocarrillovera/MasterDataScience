# %% [markdown]
# # Import JSON data

# %% [markdown]
# Vamos a importar la base de datos bikes descargada de kaggle

# %%
import json
l = open('C:/Users/alexi/Desktop/Máster Data Science para Finanzas CUNEF/ETL/bikes.json', encoding = 'utf8')
datos = json.load(l)
datos
# Out:
# {'2016': {'6': {'24': 544,
#    '7': 871,
#    '17': 464,
#    '3': 789,
#    '11': 466,
#    '25': 533,
#    '29': 719,
#    '21': 759,
#    '5': 429,
#    '16': 493,
#    '31': 3,
#    '15': 549,
#    '26': 405,
#    '18': 314,
#    '27': 733,
#    '14': 639,
#    '6': 699,
#    '9': 904,
#    '22': 777,
#    '13': 556,
#    '20': 680,
#    '28': 756,
#    '23': 767,
#    '19': 379,
#    '4': 507,
#    '12': 386,
#    '1': 747,
#    '8': 812,
#    '2': 758,
#    '30': 747,
#    '10': 549},
#   '9': {'24': 688,
#    '7': 790,
#    '17': 353,
#    '3': 492,
#    '11': 415,
#    '26': 1018,
#    '25': 291,
#    '29': 1073,
#    '21': 933,
#    '5': 723,
#    '16': 461,
#    '31': 8,
#    '15': 845,
#    '18': 327,
#    '27': 742,
#    '14': 900,
#    '6': 821,
#    '9': 379,
#    '22': 883,
#    '13': 614,
#    '20': 921,
#    '28': 1052,
#    '23': 989,
#    '19': 730,
#    '4': 461,
#    '12': 778,
#    '1': 690,
#    '8': 309,
#    '2': 761,
#    '30': 918,
#    '10': 470},
# ...

# %% [markdown]
# # Import YAML data

# %% [markdown]
# Creamos una base de datos inventada y la guardamos en formato .yaml para luego leerla

# %%
import yaml

dict_file = [{'sports' : ['soccer', 'football', 'basketball', 'cricket', 'hockey', 'table tennis']},
{'countries' : ['Pakistan', 'USA', 'India', 'China', 'Germany', 'France', 'Spain']}]

with open('C:/Users/alexi/Desktop/Máster Data Science para Finanzas CUNEF/ETL/data.yaml', 'w') as file:
    documents = yaml.dump(dict_file, file)

# %%
with open('C:/Users/alexi/Desktop/Máster Data Science para Finanzas CUNEF/ETL/data.yaml') as file:
    data_list = yaml.load(file, Loader=yaml.FullLoader)
    print(data_list)
# Out:
# [{'sports': ['soccer', 'football', 'basketball', 'cricket', 'hockey', 'table tennis']}, {'countries': ['Pakistan', 'USA', 'India', 'China', 'Germany', 'France', 'Spain']}]
